# %% [markdown]
# # Homework 2 - Considering bias in data
#
# This repository aims to perform an analysis of how the coverage of politicians on Wikipedia and the quality of articles about politicians varies among countries. For this assignment, we will combine a dataset of Wikipedia articles with a dataset of country populations, and use a machine learning service called ORES to estimate the quality of each article. We will them perform an analysis of the number of articles, and specifically high quality articles, per capita.
#
# ## License
# Snippets of the code example was developed by Dr. David W. McDonald for use in DATA 512, a course in the UW MS Data Science degree program. This code is provided under the [Creative Commons](https://creativecommons.org) [CC-BY license](https://creativecommons.org/licenses/by/4.0/). Revision 1.0 - August 15, 2023
#
# ## Step 1: Getting the Article and Population Data and analysis
#
# Data Source
#
# The Wikipedia [Category:Politicians by nationality](https://en.wikipedia.org/wiki/Category:Politicians_by_nationality) was crawled to generate a list of Wikipedia article pages about politicians from a wide range of countries which is available in the [politicians_by_country.AUG.2024.csv](HCDS/data-512-homework_2/politicians_by_country_AUG.2024.csv) file.
#
# The population data is available in CSV format as [population_by_country_AUG.2024.csv](HCDS/data-512-homework_2/population_by_country_AUG.2024.csv) used for analysis is downloaded from the [world population data sheet](https://www.prb.org/international/indicator/population/table/) published by the Population Reference Bureau.

# %%
#########
#
#    IMPORT MODULES/PACKAGES
#

# These are standard python modules
import json, time, urllib.parse
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests

# %% [markdown]
# At this step we will read and perform basic analysis on the data

# %%
# Load the CSV files
population_df = pd.read_csv('population_by_country_AUG.2024.csv')
politicians_df = pd.read_csv('politicians_by_country_AUG.2024.csv')

# Some initial analysis
print("Total number of rows in the provided politicians csv: ", politicians_df.shape[0])
print("Total number of rows in the provided popultaion csv: ", population_df.shape[0])

# find number of duplicate politicians
politicians_count_df = politicians_df.groupby(['name', 'url'])['country'].nunique().reset_index(name='country_count')
politicians_count_dup_df = politicians_count_df[politicians_count_df['country_count'] > 1]
print("Total number of politicians that are associated with more than 1 country:" ,politicians_count_dup_df.shape[0])

politicians_count_dup_df
# Out:
# Total number of rows in the provided politicians csv:  7155
# Total number of rows in the provided popultaion csv:  233
# Total number of politicians that are associated with more than 1 country: 41
#                                                    name  \
# 182                                     Abir Al-Sahlani
# 456           Aleksandr Nikitin (politician, born 1987)
# 568                                    Ali al-Qaradaghi
# 800                           Antonio Gutiérrez y Ulloa
# 815                                    Antonín Janoušek
# 892                                   Ashab Uddin Ahmad
# 1016                                       Bak Jungyang
# 1161                                        Bona Malwal
# 1495  Count Václav Antonín Chotek of Chotkov and Vojnín
# 1682                                   Djama Ali Moussa
# 1784                                    Eduard Hedvicek
# 2292                                 George Kongor Arop
# 2407                                        Goran Rakić
# 2714                                      Hrant Maloyan
# 2782                                      Ibrahim Harun
# 2961                         Jacob Magnus Sprengtporten
# 3338                                     Josip Ferfolja
# 3347                         José Alejandro de Aycinena
# 3374                           José Francisco Barrundia
# 3549                                        Juraj Košút
# 3922                                    Lazar Tomanović
# 3952             Leopold, Count von Thun und Hohenstein
# 4039                                        Luigi Adwok
# 4214                                 Manuel Carrascalão
# 4231                                    Manuel Marliani
# 4460                                     Melko Čingrija
# 4705                                     Mohammad Toaha
# 4760                          Moinuddin Ahmed Chowdhury
# 4790                                       Moshe Gutman
# 5169                                    Oliver Ivanović
# 5540                                     Rafael Montoro
# 6021                                      Sergey Abisov
# 6103                                     Shqiprim Arifi
# 6924           https://en.wikipedia.org/wiki/Yat_Hwaidi              2

# %% [markdown]
# ### API call to retrieve page info and ORES score for every article
#
# The provided list of politicians has information only about the article titles, but not about the latest revision id. To get the list of article titles with the corresponding revision ids, we make use of the [MediaWiki REST API](https://www.mediawiki.org/wiki/API:Main_page) for the EN Wikipedia. For our exact usecase, we follow the documentation at [API:Info](https://www.mediawiki.org/wiki/API:Info)
#
# When using this APi we need to setup our account on wikiMedia and generate a private API token to be used to call this API.
#
# Now you need to get the predicted quality scores for each article in the Wikipedia dataset. We're using a machine learning system called [ORES](https://www.mediawiki.org/wiki/ORES). This was originally an acronym for "Objective Revision Evaluation Service" but was simply renamed “ORES”. ORES is a machine learning tool that can provide estimates of Wikipedia article quality.
#
# We use a few constants for better readablity of the code.

# %%
#########
#
#    CONSTANTS
#

# The basic English Wikipedia API endpoint
API_ENWIKIPEDIA_ENDPOINT = "https://en.wikipedia.org/w/api.php"
API_HEADER_AGENT = 'User-Agent'

# We'll assume that there needs to be some throttling for these requests - we should always be nice to a free data resource
API_LATENCY_ASSUMED = 0.002       # Assuming roughly 2ms latency on the API and network
API_THROTTLE_WAIT = (1.0/100.0)-API_LATENCY_ASSUMED

# When making automated requests we should include something that is unique to the person making the request
# This should include an email - your UW email would be good to put in there
REQUEST_HEADERS = {
    'User-Agent': '<swarali@uw.edu>, University of Washington, MSDS DATA 512 - AUTUMN 2024'
}

# This is a string of additional page properties that can be returned see the Info documentation for
# what can be included.

PAGEINFO_EXTENDED_PROPERTIES = ""

# This template lists the basic parameters for making this
PAGEINFO_PARAMS_TEMPLATE = {
    "action": "query",
    "format": "json",
    "titles": "",           # to simplify this should be a single page title at a time
    "prop": "info",
    "inprop": PAGEINFO_EXTENDED_PROPERTIES
}

#    The current LiftWing ORES API endpoint and prediction model
#
API_ORES_LIFTWING_ENDPOINT = "https://api.wikimedia.org/service/lw/inference/v1/models/{model_name}:predict"
API_ORES_EN_QUALITY_MODEL = "enwiki-articlequality"

#
#    The throttling rate is a function of the Access token that you are granted when you request the token. The constants
#    come from dissecting the token and getting the rate limits from the granted token. An example of that is below.
#
API_LATENCY_ASSUMED = 0.002       # Assuming roughly 2ms latency on the API and network
API_THROTTLE_WAIT = ((60.0*60.0)/5000.0)-API_LATENCY_ASSUMED  # The key authorizes 5000 requests per hour

#    When making automated requests we should include something that is unique to the person making the request
#    This should include an email - your UW email would be good to put in there
#    
#    Because all LiftWing API requests require some form of authentication, you need to provide your access token
#    as part of the header too
#
REQUEST_HEADER_TEMPLATE = {
    'User-Agent': "<{email_address}>, University of Washington, MSDS DATA 512 - AUTUMN 2024",
    'Content-Type': 'application/json',
    'Authorization': "Bearer {access_token}"
}
#
#    This is a template for the parameters that we need to supply in the headers of an API request
#
REQUEST_HEADER_PARAMS_TEMPLATE = {
    'email_address' : "",         # your email address should go here
    'access_token'  : ""          # the access token you create will need to go here
}


#
#    This is a template of the data required as a payload when making a scoring request of the ORES model
#
ORES_REQUEST_DATA_TEMPLATE = {
    "lang":        "en",     # required that its english - we're scoring English Wikipedia revisions
    "rev_id":      "",       # this request requires a revision id
    "features":    True
}

#
#    These are used later - defined here so they, at least, have empty values

USERNAME = ""
ACCESS_TOKEN = ""

# %%
#   Once you've done the right set up with your Wikimedia account, it should provide you with three different keys, a Client ID,
#   a Client secret, and a Access token.

#   In this case I don't want to distribute my keys with the source of the notebook, so I wrote a key manager object that helps
#   track all of my API keys - a username and domain name retrieves the key. The key manager hides the keys on disk separate
#   from the code. A common code idiom to hide API keys will use code to extract the key from an OS environment variable. 

#   Note: if you don't want to use the key manager to help manage your API keys, you can specify the values as constants
#   below. Just don't distribute the notebook without removing the constants or you'll be distributing your key too.

USERNAME = '<your username for the wikimedia account>'
ACCESS_TOKEN = '<your private API access token>'

# %% [markdown]
# The API request will be made using one procedure. The idea is to make this reusable. The procedure is parameterized, but relies on the constants above for the important parameters. The underlying assumption is that this will be used to request data for a set of article pages. Therefore the parameter most likely to change is the article_title.
#
# Below function also incule some additional functions which are required for processing of data and create a few intermediary files

# %%
#########
#
#    PROCEDURES/FUNCTIONS
#

def request_pageinfo_per_article(article_title = None, 
                                 endpoint_url = API_ENWIKIPEDIA_ENDPOINT, 
                                 request_template = PAGEINFO_PARAMS_TEMPLATE,
                                 headers = REQUEST_HEADERS):
    
    # article title can be as a parameter to the call or in the request_template
    if article_title:
        request_template['titles'] = article_title

    if not request_template['titles']:
        raise Exception("Must supply an article title to make a pageinfo request.")

    if API_HEADER_AGENT not in headers:
        raise Exception(f"The header data should include a '{API_HEADER_AGENT}' field that contains your UW email address.")

    if 'uwnetid@uw' in headers[API_HEADER_AGENT]:
        raise Exception(f"Use your UW email address in the '{API_HEADER_AGENT}' field.")

    # make the request
    try:
        # we'll wait first, to make sure we don't exceed the limit in the situation where an exception
        # occurs during the request processing - throttling is always a good practice with a free
        # data source like Wikipedia - or any other community sources
        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        response = requests.get(endpoint_url, headers=headers, params=request_template)
        json_response = response.json()
    except Exception as e:
        print(e)
        json_response = None
    return json_response

# Function to read article titles from the CSV file
def read_article_file(file_path):
    """
    Read the article titles from a CSV file.

    Args:
    - file_path (str): Path to the CSV file containing article titles.

    Returns:
    - list: A list of article titles extracted from the 'name' column of the CSV file.

    """
    try:
        # Read the CSV file into a DataFrame
        df = pd.read_csv(file_path)

        # Check if 'name' column exists and extract titles
        if 'name' in df.columns:
            article_titles = df['name'].tolist()
        else:
            print(f"Error: 'name' column not found in the CSV file.")
            return []
    except FileNotFoundError:
        print(f"Error: CSV file '{file_path}' not found. Please check the file path and try again.")
        raise
    except Exception as e:
        print(f"Unexpected error while reading '{file_path}': {e}")
        raise
    
    return article_titles


# iterate over article and save info in a json
def fetch_and_save_article_info(article_list):
    """
    Process the Wikipedia API data for each article and save it as a JSON file.

    Args:
    - article_list (list): List of article titles to query from the Wikipedia API.

    Returns:
    - None
    """
    wiki_information = {}
    batch_size = 50  # Set the batch size for requests

    # Fetch information in batches
    for i in range(0, len(article_list), batch_size):
        batch_articles = article_list[i:i + batch_size]
        names = '|'.join(batch_articles)
        print(f"Fetching information for batch: {batch_articles}")
        
        info = request_pageinfo_per_article(names)
        
        if 'query' in info and 'pages' in info['query']:
            response = info['query']['pages']
            for page_id, page_info in response.items():
                name = page_info['title']
                wiki_information[name] = page_info
        else:
            print(f"No valid response for batch starting with {batch_articles[0]}")

    # Write the information to a single JSON file
    output_file = "./intermediary_files/articles_page_info.json"
    try:
        with open(output_file, 'w', encoding='utf-8') as json_file:
            json.dump(wiki_information, json_file, ensure_ascii=False, indent=4)
        print(f"Data successfully saved to {output_file}.")
    except Exception as e:
        print(f"Error saving data to JSON: {e}")


# function API call to get the quality score for every article
def request_ores_score_per_article(article_revid = None, email_address=None, access_token=None,
                                   endpoint_url = API_ORES_LIFTWING_ENDPOINT, 
                                   model_name = API_ORES_EN_QUALITY_MODEL, 
                                   request_data = ORES_REQUEST_DATA_TEMPLATE, 
                                   header_format = REQUEST_HEADER_TEMPLATE, 
                                   header_params = REQUEST_HEADER_PARAMS_TEMPLATE):
    
    #    Make sure we have an article revision id, email and token
    #    This approach prioritizes the parameters passed in when making the call
    if article_revid:
        request_data['rev_id'] = article_revid
    if email_address:
        header_params['email_address'] = email_address
    if access_token:
        header_params['access_token'] = access_token
    
    #   Making a request requires a revision id - an email address - and the access token
    if not request_data['rev_id']:
        raise Exception("Must provide an article revision id (rev_id) to score articles")
    if not header_params['email_address']:
        raise Exception("Must provide an 'email_address' value")
    if not header_params['access_token']:
        raise Exception("Must provide an 'access_token' value")
    
    # Create the request URL with the specified model parameter - default is a article quality score request
    request_url = endpoint_url.format(model_name=model_name)
    
    # Create a compliant request header from the template and the supplied parameters
    headers = dict()
    for key in header_format.keys():
        headers[str(key)] = header_format[key].format(**header_params)
    
    # make the request
    try:
        # we'll wait first, to make sure we don't exceed the limit in the situation where an exception
        # occurs during the request processing - throttling is always a good practice with a free data
        # source like ORES - or other community sources
        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        #response = requests.get(request_url, headers=headers)
        response = requests.post(request_url, headers=headers, data=json.dumps(request_data))
        json_response = response.json()
    except Exception as e:
        print(e)
        json_response = None
    return json_response


# read the json file with article title and last rev id and get quality scores
def process_ores_scores_from_json(json_file_path, email_address, access_token):
    """
    Get ORES scores for articles from a JSON file and save them to a CSV file.

    Args:
        json_file_path (str): Path to the JSON file containing article page information.
        email_address (str): Your email address for the API request.
        access_token (str): Your access token for the API request.
    """
    
    output_csv = 'intermediary_files/articles_ores_scores.csv'
    all_article_scores = []
    
    try:
        # Load the JSON file
        with open(json_file_path, mode='r', encoding='utf-8') as json_file:
            articles = json.load(json_file)

            for article in articles.values():  # Assuming articles is a dictionary
                lastrevid = article.get('lastrevid')
                
                if lastrevid:
                    print(f"Requesting ORES score for revision ID: {lastrevid}")
                    response = request_ores_score_per_article(
                        article_revid=lastrevid,
                        email_address=email_address,
                        access_token=access_token
                    )
                    
                    if response is not None:
                        # Process the response and store the scores
                        score_data = {
                            'revision_id': lastrevid,
                            'quality_prediction': response.get('enwiki', {}).get('scores', {}).get(str(lastrevid), {}).get('articlequality', {}).get('score', {}).get('prediction')
                        }

                        # Extract probabilities
                        probabilities = response.get('enwiki', {}).get('scores', {}).get(str(lastrevid), {}).get('articlequality', {}).get('score', {}).get('probability', {})
                        score_data.update({f'Probability {key}': value for key, value in probabilities.items()})
                        
                        all_article_scores.append(score_data)
                    else:
                        print(f"Failed to get score for lastrevid {lastrevid}")
                else:
                    print("lastrevid not found for an article.")
        
        # Save the scores to a CSV file
        all_article_scores_df = pd.DataFrame(all_article_scores)
        all_article_scores_df.to_csv(output_csv, index=False)
        print(f"Scores saved to {output_csv}")

    except FileNotFoundError:
        print(f"Error: JSON file '{json_file_path}' not found. Please check the file path and try again.")
        raise
    except json.JSONDecodeError:
        print(f"Error: Failed to decode JSON from '{json_file_path}'.")
        raise

# %% [markdown]
# ## Step 2: Getting Article Quality Predictions
#
# ORES estimates the quality of an article (at a particular point in time), and assigns a series of probabilities that the article is in one of 6 quality categories. The options are, from best to worst:
#
#     FA - Featured article(high quality)
#     GA - Good article(high quality)
#     B - B-class article
#     C - C-class article
#     Start - Start-class article
#     Stub - Stub-class article
#
# We run the below cell to get the artcile titles from the csv files and get the lastest revision id for a politician article using the page info API and save it to a json file.
#
# There is a way to get the information for multiple pages at the same time, as implemented in 'fetch_and_save_article_info' function by separating the page titles with the vertical bar "|" character. However, this approach has a limit - the API can handle requests with upto 50 article titles appended. Reference documentation can be found [here](https://www.mediawiki.org/w/api.php?action=help&modules=query)

# %%
# Read the article titles from the CSV
article_titles = read_article_file("./politicians_by_country_AUG.2024.csv")
# Process and save data for all articles
fetch_and_save_article_info(article_titles)
# Out:
# Fetching information for batch: ['Majah Ha Adrif', 'Haroon al-Afghani', 'Tayyab Agha', 'Khadija Zahra Ahmadi', 'Aziza Ahmadyar', 'Muqadasa Ahmadzai', 'Mohammad Sarwar Ahmedzai', 'Amir Muhammad Akhundzada', 'Nasrullah Baryalai Arsalai', 'Abdul Rahim Ayoubi', 'Ismael Balkhi', 'Abdul Baqi Turkistani', 'Mohammad Ghous Bashiri', 'Jan Baz', 'Bashir Ahmad Bezan', 'Rafiullah Bidar', 'Mohammad Siddiq Chakari', 'Cheragh Ali Cheragh', 'Nasir Ahmad Durrani', 'Muhammad Hashim Esmatullahi', 'Ezatullah (Nangarhar)', 'Aimal Faizi', 'Gajinder Singh Safri', 'Sharif Ghalib', 'Hashmat Ghani Ahmadzai', 'Abdul Ghani Ghani', 'Ghulam Ghaus', 'Ghulam Muhammad Ghobar', 'Mohammad Gul (Helmand Council)', 'Sayed Yousuf Halim', 'Rangina Hamidi', 'Sayed Zafar Hashemi', 'Qutbuddin Hilal', 'Mahboba Hoqomal', 'Musa Hotak', 'Mirza Muhammad Ismail', 'Sayed Jalal', 'Said Tayeb Jawad', 'Sayed Jalal Karim', 'Hafizullah Shabaz Khail', 'Masoud Khalili', 'Mohammad Khan (athlete)', 'Samoud Khan', 'Baran Khan Kudezai', 'Azizullah Lodin', 'Razaq Mamoon', 'Fazel Ahmed Manawi', 'Moeen Marastial', 'Ahmad Wali Massoud', 'Mohammad Daud Miraki']
# Fetching information for batch: ['Abdul Sattar Mirzakwal', 'Abdul Karim Misaq', 'Ali Mohammad (politician)', 'Nasruddin Mohseni', 'Davood Moradian', 'Zalmai Mujadidi', 'Sardar Mohammad Nadir Naeem', 'Daoud Naji', 'Gholam Rabani Nasher', 'Ghulam Faroq Nijrabi', 'Zabih-U-llah Ghazi Noristani', 'Mohammed Tahir Omar', 'Mohammed Qalamuddin', 'Ghulam Mohammad Rigi', 'Ghulam Hassan Safi', 'Hanifa Safi', 'Mohammed Zia Salehi', 'Abdul Majid Samim', 'Saber Sangar', 'Sayed Nasim Mihanparast', 'Suhail Shaheen', 'Fazal Hadi Shinwari', 'Baktash Siawash', 'Hasan Ali Sultani', 'Mohammad Hashem Taufiqui', 'Pacha Gul Wafadar', 'Wahidullah Waissi', 'Ahmadullah Wasiq', 'Gul Ahmmad Yama', 'Abdul Salam Zaeef', 'Abdul Zahir (Konar Education Minister)', 'Mohammed Zaman', 'Ziauddin (Afghan militia leader)', 'Qari Ziauddin', 'Abdul Ghafor Zori', 'Ali Pasha of Gusinje', 'Ylli Asllani', 'Azis Tahir Ajdonati', 'Bislim Bajgora', 'Kastriot Berissa', 'Bardhok Biba', 'Kostandin Boshnjaku', 'Spartak Braho', 'Safet Butka', 'Uran Butka', 'Refo Çapari', 'Neritan Ceka', 'Hysni Curri', 'Ibrahim Dalliu', 'Niazi Demi']
# Fetching information for batch: ['Abdurrahman Dibra', 'Bujar Dida', 'Ahmed Dino', 'Rasih Dino', 'Ferhat Bey Draga', 'Nexhip Draga', 'Aqif Pasha Elbasani', 'Abas Ermenji', 'Qamil Musa Haxhi Feza', 'Themistokli Gërmenji', 'Sabri Godo', 'Mihal Grameno', 'Aćif Hadžiahmetović', 'High Council of Regency', 'Kurt Agë Kadiu', 'Mehmed Kalakula', 'Alfred Karamuço', 'Ibrahim Karbunara', 'Ali Këlcyra', 'Bajram Kelmendi', 'Kristo Kirka', 'Elez Koçi', 'Xhelal Koprëncka', 'Kryeziu family', 'Artur Kuko', 'Xhavid Leskoviku', 'Sabit Lulo', 'Gjon Markagjoni', 'Tefik Mborja', 'Hysni Milloshi', 'Musa Qazimi', 'Mustafa Ndroqi', 'Behxhet Nepravishta', 'Adrian Neritani', 'Sali Nivica', 'Thoma Orologa', 'Bedri Pejani', 'Kadri Prishtina', 'Ymer Prizreni', 'Avni Rustemi', 'Chatin Sarachi', 'Nebi Sefa', 'Eduard Shalsi', 'Ylli Vesel Shehu', 'Athanas Shundi', 'Xhelal Sveçla', 'Mehmet Tahsini', 'Ibrahim Temo', 'Afrim Tole', 'Syreja Vlora']
# Fetching information for batch: ['Visarion Xhuvani', 'Visar Ymeri', 'Abdyl Ypi', 'Xhezair Zaganjori', 'Menduh Zavalani', 'Abdelkader Zoukh', 'Chaâbane Aït Abderrahim', 'Ali Aoun', 'Basma Azouar', 'Mohamed Seghir Babes', 'Noureddine Bahbouh', 'Lamine Bechichi', 'Aïssa Bekkai', 'Abdelhakim Belabed', 'Mohamed Tarek Belaribi', 'Kamel Beldjoud', 'Aboubakr Belkaid', 'Youcef Belmehdi', 'Mohamed Cherif Belmihoub', 'Mohamed Belouizdad', 'Benaouda Hadj Hacène Bachterzi', 'Souad Bendjaballah', 'Abdelkrim Benmbarek', 'Mohamed Bensalam', 'Fayçal Bentaleb', 'Ahmed Bidani', 'Kamel Bidari', 'Rachid Bladehane', 'Saïd Boualam', 'Rabah Bouaziz', 'Abdeslam Bouchouareb', 'Ibrahim Boughali', 'Yahia Boukhari', 'Mohamed Bouslimani', 'Foued Chehat', 'Hamza Al Sid Cheikh', 'Hocine Cherhabil', 'Abderrahmane Meziane Chérif', 'Saïd Chibane', 'Brahim Chibout', 'Youcef Chorfa', 'Fazia Dahleb', 'Taha Derbal', 'Nassim Diafat', 'Mokhtar Didouche', 'Bouras Djamel', 'Fatiha Serour', 'Ahmed Hamiani', 'Nadir Kassab', 'Brahim Djamel Kassali']
# Fetching information for batch: ['Kaoutar Krikou', 'Sassi Lamouri', 'Mohamed Maghlaoui', 'Amar Makhloufi', 'Yassine Merabi', 'Brahim Merad', 'Bachir Messaitfa', 'Azzedine Mihoubi', 'Mohamed Ali Boughazi', 'Amar Mohammedi', 'Samia Moualfi', 'Soraya Mouloudji', 'Yacine Oualid', 'Cherif Rahmani', 'Lakhdar Rakhroukh', 'Laid Rebiga', 'Kamel Rezig', 'Salim Saadi', 'Abdelhak Saihi', 'Hichem Sofiane Salaouatchi', 'Naima Salhi', 
ámaso Centeno', 'Rossana Chahla', 'Lázaro Chiappe', 'Carlos Corach', 'Jorge Coscia', 'Carlos de la Rosa', 'Juan Carlos Del Bello', 'Luis L. Domínguez', 'Máximo Etchecopar', 'Héctor Toty Flores', 'Guillermo Francos', 'Juan Fugl', 'Santiago Gallo', 'Manuel José García', 'Juan José Gómez Centurión', 'Luis Carlos Gómez Centurión', 'Martín Guzmán', 'Federico Helguera']
# Fetching information for batch: ['Fernando Iglesias (Argentine politician)', 'Ricardo Kennedy', 'Carlos Kunkel', 'Norberto La Porta', 'Andrés Larroque', 'Julián de Leyva', 'Mónica López (politician)', 'Lucio Victorio Mansilla', 'Nicolás Massot', 'Martín Menem', 'Juan Mignaburu', 'Guillermo Montenegro', 'Mariano Moreno', 'Marcelo Muniagurria', 'Fernando Nadra', 'Rómulo Sebastián Naón', "Santiago G. O'Farrell", 'Alfredo Olmedo', 'Miguel Ángel Pesce', 'Carlos Petroni', 'Alejo Peyret', 'Aldo Pignanelli', 'Abel Posse', 'Enrique S. Quintana', 'Amán Rawson', 'Martín Sabbatella', 'Juan Pablo Schiavi', 'Héctor Tizón', 'Claudio Uberti', 'Arístides Villanueva', 'Jorge Yoma', 'Ashot Arsenyan', 'Vigen Chitechyan', 'Hayk Chobanyan', 'Gurgen Egiazaryan', 'Parunak Ferukhan', 'Gevorg Ghazaryan (politician)', 'Andrias Ghukasyan', 'Aram Grigoryan (politician)', 'Vahagn Hovakimyan', 'Tigran Karapetyan', 'Tigran Khzmalyan', 'Mikayel Kotanyan', 'Hrant Maloyan', 'Khachatur Malumian', 'Aram Manukyan', 'Gevorg Melik-Karagyozyan', 'Vahan Minakhoryan', 'Ruben Miroyan', 'Ruben Mirzakhanyan']
# Fetching information for batch: ['Badal Muradyan', 'Narine Tukhikyan', 'Gabriel Noradoungian', 'Israel Ori', 'Paul Paul', 'Garo Paylan', 'Genrikh Poghosyan', 'Ishkhan Saghatelyan', 'Karen Sargsyan (sociologist)', 'Martiros Sarukhanyan', 'Vartkes Serengülian', 'Suren Shadunts', 'Ohannes Tchekidjian', 'Hrayr Tovmasyan', 'Usub Bek Temuryan', 'Kegham Vanigian', 'Serop Zakaryan', 'Alfons Adam', 'Ingo Appelt', 'Maximilian Anton Karl, Count Baillet de Latour', 'Heinrich Alfred Barb', 'Leopold Berchtold', 'Joseph Buttinger', 'Prince Carl of Solms-Braunfels', 'Count Václav Antonín Chotek of Chotkov and Vojnín', "Citizens' Ministry", 'Richard von Coudenhove-Kalergi', 'Franz Dinghofer', 'George Abraham von Dyhrn', 'Eduard von Grebmer zu Wolfsthurn', 'Barbara Eibinger-Miedl', 'Hans Ferlitsch', 'Friedhelm Frischenschlager', 'Walter Guggenberger', 'Ulrich Habsburg-Lothringen', 'Ernst Hampel (politician)', 'Hans Peter Haselsteiner', 'Friedrich Wilhelm von Haugwitz', 'Eduard Hedvicek', 'Hermann Stern', 'Jürgen Himmelbauer', 'Anton Hofer', 'Andreas Hörtnagl', 'Franz Jetzinger', 'Konstantin Jireček', 'Hugo Jury', 'Joseph Kenner', 'Theodor Kery', 'Michael Killisch-Horn', 'Sophia Kircher']
# Fetching information for batch: ['Botche Candé', 'Juliano Fernandes', 'Teodora Inácia Gomes', 'Desejado Lima da Costa', 'Aristide Menezes', 'Florentino Mendes Pereira', 'Carmelita Pires', 'Agnelo Regalla', 'Nataniel Aguirre', 'Francisco Argandoña', 'Atanasio de Urioste Velasco', 'Isaac Ávalos', 'Augusto Céspedes', 'Adolfo Chávez', 'Chi Hyun Chung', 'Pantaleón Dalence', 'Rafael Peña', 'Marcelo Elío', 'Marcial Fabricano', 'Fernando Eloy Guachalla', 'Toribia Lero Quispe', 'Antonio Machaca', 'Adolfo Mendoza', 'Manuel de Molina Zamudio', 'Pedro Domingo Murillo', "Francisco Burdett O'Connor", 'Manuel Luis de Oliden', 'Simón Iturri Patiño', 'Bonifacio Pinedo', 'Julio Pinedo', 'Gary Prado Salmón', 'José Mariano Serrano', 'Moisés Torres (politician)', 'Fernando Vargas Mosua', 'Jaime de Zudáñez', 'Kemal Ademović', 'Mehmed Alajbegović', 'Boško Baškot', 'Salko Bukvarević', 'Sabina Ćudić', 'Dženan Đonlagić', 'Edin Forto', 'Dževad Galijašević', 'Josip Grubeša', 'Ankica Gudeljević', 'Hakija Hadžić', 'Mirsad Hadžikadić', 'Sanjin Halimović', 'Sevlid Hurtić', 'Husein Miljković']
# Fetching information for batch: ['Jasmin Imamović', 'Adamir Jerković', 'Esed Kadrić', 'Mehmed Kapetanović', 'Osman Karabegović', 'Rusmir Mahmutćehajić', 'Amor Mašović', 'Božidar Matić', 'Dragan Mektić', 'Ademaga Mešić', 'Jelka Miličević', 'Abdulah Mutapčić', 'Abdulah Nakaš', 'Damir Nikšić', 'Ismet Popovac', 'Hakija Pozderac', 'Hamdija Pozderac', 'Nurija Pozderac', 'Đuro Pucar', 'Svetozar Pudarić', 'Alen Šeranić', 'Uglješa Uzelac', 'Nezir Škaljić', 'Ibrahim Spahić', 'Jelena Trivić', 'Milan Uzelac', 'Dragan Vikić', 'Miloš Vukašinović', 'Philip Matante', 'Leetile Disang Raditladi', 'Patrick van Rensburg', 'Tobias de Aguiar', 'Medeiros e Albuquerque', 'Léo de Almeida Neves', 'Antônio Pinto Chichorro da Gama', 'Cipriano Barata', 'Jader Barbalho Filho', 'Irani Barbosa', 'Djalma Bastos de Morais', 'Henrique de Beaurepaire-Rohan, Viscount of Beaurepaire-Rohan', 'Natália Bastos Bonavides', 'Marcos Braz', 'Amador Bueno', 'Maurício Campos de Medeiros', 'Marcelo Cecé', 'Izolda Cela', 'Margarete Coelho', 'Paulo Corrêa', 'Miguel Couto', 'João Cunha (politician)']
# Fetching information for batch: ['Ivan Dimov (scientist)', 'Valentin Fortunov', 'Tsoncho Ganev', 'Georgi Gvozdeykov', 'Goritsa Grancharova', 'Ivancho Hadzhipenchovich', 'Ivan Demerdzhiev', 'Aleksi Ivanov', 'Grozdan Karadzhov', 'Vladimir Karolev', 'Georgi Kirkov', 'Spiro Kitinchev', 'Ivan Kondov', 'Kostadin Kostadinov (professor)', 'Gavril Krastevich', 'Petar Kulenski', 'Lazar Lazarov', 'Nikola Lazarov', 'Ivan Marazov', 'Venko Markovski', 'Yakov Matakiev', 'Ilian Mihov', 'Raya Nazaryan', 'Nikolay Milkov', 'Plamen Panayotov', 'Vladislav Panev', 'Asparuh Panov', 'Atanas Pekanov', 'Sasho Penov', 'Lyudmila Petkova', 'Hristo Petrov', 'Rosen Plevneliev', 'Aleksandur Pulev', 'Denitsa Simeonova', 'Ivan Stanchov', 'Kalin Stoyanov', 'Stanislav Stoyanov (politician)', 'Dragomir Stoynev', 'Teodora Genchovska', 'Daniel Valchev', 'Krasimir Valchev', 'Velko Valkanov', 'Ventsislav Varbanov', 'Damyan Velchev', 'Svetoslav Vitkov', 'Mincho Yovchev', 'Atanas Zafirov', 'Martin Zaimov', 'Dragomir Zakov', 'Nayden Zelenogorski']
# Fetching information for batch: ['Boureima Badini', 'Blaise Bassoleth', 'Nazi Boni', 'Eric Bougouma', 'François Compaoré', 'Daniel Ouezzin Coulibaly', 'Toubé Clément Dakio', 'Frédéric Guirma', 'Emile Ilboudo', 'Zinda Kaboré', 'Christophe Kalenzaga', 'Joséphine Drabo Kanyoulou', 'Joséphine Ki-Zerbo', 'Begnon-Damien Koné', 'Yabre Juliette Kongo', 'Kouamé Lougué', 'Jean-Baptiste Natama', 'Jean-Baptiste Ouédraogo', 'Mamadou Ouédraogo', 'Ousmane Bougouma', 'Pargui Emile Paré', 'Filippe Savadogo', 'Nouhoun Sigue', 'Diongolo Traore', 'Maurice Yaméogo', 'Saye Zerbo', 'Aung Than Oo', 'Aye Ko (artist)', 'Ba Shin', 'Bao Youxiang', 'Bawk Ja', 'Cheery Zahau', 'Oscar de Glanville', 'M. A. Gaffar', 'Han Tha Myint', 'Hla Maung Shwe', 'Hso Khan Pha', 'Nai Htaw Sorn', 'Htay Aung (businessman)', 'Htin Linn Aung', 'Ja Htoi Pan', 'Khin Kyaw Han', 'Khin Ma Ma Myo', 'Khin Maung Swe', 'Khun San Lwin', 'Ko Ni', 'Thakin Kodaw Hmaing', 'Kwe Te No', 'Sao Kya Seng', 'Kyaw Moe Tun']
# Fetching information for batch: ['Kyaw Myint', 'Kyaw Tun', 'Kyaw Zaw Oo', 'Duwa Lashi La', 'Lian Hmung Sakhong', 'Sultan Mahmud (minister)', 'Maran Brang Seng', 'Gani Markan', 'Maw Htun Aung', 'Myint Swe (politician, born 1965)', 'Myo Yan Naung Thein', 'Naw Ohn Hla', 'Nay Myo Wai', 'Nay Zin Lat', 'Kyaw Ni', 'Nyi Sein', 'Nyo Nyo Thin', 'Pu Pa Thang', 'San Tun', 'Sao Sanda', 'Sasa (politician)', 'Saw Sa', 'Saya Gyi U Nu', 'Sein Win (politician, born 1944)', 'Mya Lay Sein', 'Sao Seng Suk', 'Shwe Ohn', 'Soe Moe Hlaing', 'Sultan Ahmed (Burmese politician)', 'Naw Susanna Hla Hla Soe', 'Tan Yu Sai', 'Taw Phaya Galay', 'Tayzar San', 'Than Nyein', 'Than Sein', 'Than Win', 'Thaung Tun (politician)', 'Baganset U Thaw', 'Thein Maung', 'Thein Nyunt (politician)', 'Thet Win Aung', 'Thirty Comrades', 'Tin Aye', 'Tu Hkawng', 'Wai Moe Naing', 'Win Ko Ko Latt', 'Maung Wuntha', 'Yawd Serk', 'Za Hlei Thang', 'Zaw Htay']
# Fetching information for batch: ['Zura Begum', 'Pierre Baranyanka', 'Joseph Biroli', 'Evelyne Butoyi', 'Joseph Cimpaye', 'Edouard Nduwimana', 'Gervais Nyangoma', 'Gérard Mfuranzima', 'Cyrille Ndayirukiye', 'Révérien Ndikuriyo', 'Tharcisse Niyongabo', 'Gabriel Nizigama', 'Jean-Baptiste Ntidendereza', 'Ririkumutima', 'Agathon Rwasa', 'Imelde Sabushimike', 'Alexis Sinduhije', 'Ang Vong Vathana', 'Samheng Boros', 'Bun Chanmol', 'Chem Snguon', 'Chhan Sokhom', 'Chuon Saodi', 'Duong Sam Ol', 'Ieu Koeus', 'Ith Samheng', 'Khem Veasna', 'Kou Roun', 'Daran Kravanh', 'Lon Nil', 'Mao Ayuth', 'Neav Sithong', 'Ngoun Chhay Kry', 'Norodom Norindeth', 'Norodom Phurissara', 'Oung Ouen', 'Phlek Chhat', 'Ponn Vongs Vaddey', 'Samheng Bora', 'Say Phouthang', 'Sisowath Youtevong', 'So Nem', 'Tep Hun', 'Tep Phan', 'Tep Vattho', 'Thiounn', 'Touch Kim', 'Truong Cang', 'Tuot Saron', 'Uch Ven']
# Fetching information for batch: ['Uk Vithun', 'Ung Hong Sath', 'Veng Sakhon', 'Yat Hwaidi', 'Marie Catherine Abena', 'Haman Adama', 'Vincent de Paul Ahanda', 'Ahmadou Ahidjo', 'Joseph Beti Assomo', 'Charles Ateba Eyene', 'Olivier Bilé', 'Dsamou Micheline', 'Lawrence Fonka Shang', 'Victor Fotso', 'Séraphin Magloire Fouda', 'Lucy Gwanmesia', 'Njomgang Isaac', 'René Jam Afane', 'Augustine Ngom Jua', 'Paul Monyonge Kale', 'Enanga Kebbi', 'Pierre Kotouo', 'Laurentine Mbede', 'Albert Mbida', 'Ibrahim Mbombo Njoya', 'Clémentine Ananga Messina', 'Ousmane Mey', 'Victor Mukete', 'Bernard Muna', 'Jerôme Mvondo', 'Anne Marthe Mvoto', 'Hermine Patricia Tomaïno Ndam Njoya', 'Pierre Ngayewang', 'John Ebong Ngole', 'Xavier Ngoubeyou', 'Victor Anomah Ngu', 'Julienne Niat', 'Dorothy L. Njeuma', 'Bernard Njonga', "Arouna N'Joya", 'Edouard Nomo-Ongolo', 'Antoine Ntsimi', 'André Ngongang Ouandji', 'Paul Pondi', 'Félix Sabal Lecco (politician)', 'François Sengat-Kuo', 'Madeleine Tchuente', 'Félix Tonye Mbog', 'Kah Walla', 'Zakiatou Djamo']
# Fetching information for batch: ['José Manuel Gomes Andrade', 'Honório Barreto', 'Pedro Fernandes Lopes', 'Januaria Moreira', 'Paulo Rocha (Cape Verde politician)', 'Gilberto Correia Carvalho Silva', 'Luís Filipe Tavares', 'Carlos de Vasconcelos', 'Abraão Vicente', 'Jean-Bédel Bokassa', 'Antoine Darlan', 'Georges Darlan', 'Catherine Denguiadé', 'Henri-Marie Dondra', 'Saif Durbar', "Gaston N'Guérékata", 'Jean-Benoît Gonda', 'Hassan Al Habib', 'Rodolphe Iddi Lala', 'Désiré Kolingba', "Tchakpa M'brede", 'Karim Meckassoua', 'Abakar Sabone', 'Levy Yakete', 'Achta Ahmat Bremé', 'Kamougue Assoum', 'Christian Georges Diguimbaye', 'Firmin Djidingar', 'Roger Djikisna', 'Issa Doubragne', 'Moussa Faki', 'Arabi El Goni', 'Isabelle Kassire', 'Oueddei Kichidemi', 'Alphonse Kotiga', 'Baba Laddé', 'Nadji Madou', 'Mahmoud Ali Seid', 'Mariam Mahamat Nour', 'Laoukein Kourayo Médard', 'Abbo Nassour', 'Tahir Hamid Nguilin', 'Quatre Sou Quatre', 'François Tombalbaye', 'Saadie Goukouni Weddeye', 'Alejandro Serani Burgos', 'Beltrán Mathieu', 'Alexandra Benado', 'Rolando Calderón', 'Eugenio Cantuarias']
# Fetching information for batch: ['Carlos Balmaceda Saavedra', 'Jorge Cauas', 'Alberto Cooper', 'Fernando Cordero Rusque', 'Juan de Dios Correa de Saa', 'María Silvia Correa Marín', 'Álvaro Covarrubias', 'Pedro Nolasco Cruz Vergara', 'Jose Fernandez Dubrock', 'Juan Egaña', 'Sergio Fernández Fernández', 'Ángel Flisfisch', 'Jaime Gazmuri', 'Carlos González Márquez', 'David Henríquez (footballer, born 1977)', 'Alejandra Bravo Hidalgo', 'Checho Hirane', 'Ricardo Hormazábal', 'Aucán Huilcamán', 'Liliana Jadue', 'Andrés Jouannet', 'Antonio Leal Labrín', 'Graciela Mandujano', 'Daniel Manouchehri', 'Rodrigo Mundaca', 'Sergio Ortega (composer)', 'Manuel Ossa Ruiz', 'Miguel Otero Lathrop', 'Sergio Páez Verdugo', 'Luis Palacios Rossini', 'Héctor Parra (footballer)', 'Ignacio Pérez Walker', 'Bernhard Eunom Philippi', 'Germán Picó Cañas', 'Tancredo Pinochet', 'Jaime Pizarro', 'Roberto Poblete', 'Francisco Prat Alemparte', 'Pablo Prieto', 'Valentina Quiroga', 'Patricio Rey Sommer', 'Claudio Reyes', 'Mario Ríos Santander', 'Jennifer Rojas', 'Miguel Schweitzer Walters', 'Loreto Silva', 'Roberto Thieme', 'Manuel Antonio Tocornal', 'Ramón Vega Hidalgo', 'Juan de Dios Vial del Río']
# Fetching information for batch: ['Claudio Vicuña Subercaseaux', 'Hernán Vodanovic', 'Chris Watson', 'Sergio Zarzar Andonie', 'Cao Lihuai', 'Fu Wenhua', 'Gu Shu', 'Hang Yihong', 'Hao Hongjun', 'Hoi Lai Fong', 'Hu Fuming', 'Jiao Xiaoping', 'Lin Shengzhong', 'Lu Feng (politician)', 'Shi Ping (politician)', 'Wang
# Fetching information for batch: ['Manuel Dorta-Duque', 'Carlos Fernández Gondín', 'Orestes Ferrara', 'Porfirio Franca', 'Francisco de Arango y Parreño', 'Edith García Buchaca', 'Eumelín González Sánchez', 'Aurelio Hevia', 'Fernando Heydrich', 'Alfredo Hornedo', 'José Irisarri', 'Perfecto Lacoste', 'José Francisco Lemus', 'Manuel Marrero Cruz', 'Rubén Martínez Puente', 'Augusto Martínez Sánchez', 'Bartolomé Masó', 'Ramón Meza y Suárez Inclán', 'Rafael Montoro', 'Bartolomé Morales', 'José Núñez de Cáceres', 'Juan Vitalio Acuña Núñez', 'Frank País', 'Pedro Esteban González-Larrinaga', 'Guillermo Portela', 'Juan Nepomuceno de Quesada', 'Luis Alberto Rodríguez López-Calleja', 'Francisco Sánchez Betancourt', 'Salvador José de Muro, 2nd Marquis of Someruelos', 'Laureano de Torres y Ayala', 'Salvador Valdés Mesa', 'Antonio Zambrana', 'Mine Atlı', 'Christos Christou (politician)', 'Ioannis Clerides', 'Katherine Clerides', 'Takis Evdokas', 'Oz Karahan', 'Stelios Koiliaris', 'Andreas Koukouma', 'Pantelis Kouros', 'Kyrillos III of Cyprus', 'Michalis Paraskevas', 'Christos Patsalides', 'Nicos A. Rolandis', 'Benon Sevan', 'Stefanos Stefanou', 'Michael Zampelas', 'Josef Barák', 'Dagmar Burešová']
# Fetching information for batch: ['František Ringo Čech', 'Jaroslav Chalupský', 'Count Václav Antonín Chotek of Chotkov and Vojnín', 'Petr Cibulka', 'Josef Šebestián Daubek', 'Karel Domin', 'Jaroslav Foldyna', 'Vladimír Franz', 'Josef Václav Frič', 'Radola Gajda', 'Julius Gregr', 'Tomáš Grulich', 'Karel Havlík', 'Eduard Hedvicek', 'Vladimír Hučín', 'Stanislav Huml', 'Martin Jahn', 'Antonín Janoušek', 'Josef Ježek', 'Ladislav Jirků', 'Svatopluk Karásek', 'Wenzel Anton, Prince of Kaunitz-Rietberg', 'Philip Kinsky of Wchinitz and Tettau', 'Bohuslav Kokotek', 'Jiří Kopal', 'Jan Krejčí', 'Tomáš Kvapil', 'Jan Lacina', 'Lubomír Ledl', 'Miroslav Lidinský', 'Jiří Lobkowicz', 'Jiří Löw', 'Ivan Mašek', 'Mikuláš of Hus', 'Zdeněk Mraček', 'Jana Nečasová', 'Joseph Nekl', 'Jiří Oberfalzer', 'Roman Onderka', 'Vladimír Oplt', 'Mojmír Povolný', 'Vladimír Príkazský', 'Ondřej Přikryl', 'Jozef Regec', 'František Reichel', 'Bedřich Reicin', 'Richard Sacher', 'Tomáš Eduard Šilinger', 'Karel Sladkovský', 'Karel Štogl']
# Fetching information for batch: ['Matěj Stropnický', 'Jiří Svoboda (director)', 'Miroslav Tetter', 'Leopold, Count von Thun und Hohenstein', 'Tomáš Vandas', 'Jiří Ventruba', 'Jan Vrba (politician)', 'Stanislav Žalud', 'Moussa Ali Abdoulkader', 'Djama Ali Moussa', 'Choukri Djibah', 'Omar Farah Iltireh', 'Daher Ahmed Farah', 'Ahmed Goumane-Roble', 'Halo Mohamed Ibrahim', 'Barkat Gourad Hamadou', 'Mahmoud Harbi', 'Abdallah Barkat Ibrahim', 'Mohamed Kamil', 'Mahamoud Moustapha Daher', 'Ahmed-Idriss Moussa', 'Omar Osman Rabe', 'Mohamed Warsama Ragueh', 'President of the Dominican Republic', 'Johnny Abbes', 'José Rafael Abinader', 'Yamil Abreu Navarro', 'Roberto Álvarez Gil', 'Casimiro Antonio Marte Familia', 'Ramón Marrero Aristy', 'José María Cabral y Báez', 'José María Caminero', 'Miguel Cocco', 'Ramón Tapia Espinal', 'Viriato Fiallo', 'Franklin Franco', 'José Gabriel García', 'Rosa Gómez de Mejía', 'Maximiliano Gómez', 'Juan Isidro Jimenes Grullón', 'Isabel Mayer', 'Valentin Medrano Pérez', 'Miguel Mejía (politician)', 'Matías Ramón Mella', 'Guillermo Moreno García', 'Juan Vicente Moscoso', 'José Ignacio Paliza', 'Porfirio Andrés Bautista García', "Emilio Prud'Homme", 'Ramón Antonio Ramírez']
# Fetching information for batch: ['Roberto Salcedo Sr.', 'Juan Sánchez Ramírez', 'Francisco del Rosario Sánchez', 'Julián Serulle', 'Josefina Stubbs', 'Tomás Pimentel', 'Jack Veneno', 'Geovanny Vicente', 'Abelardo Vicioso', 'Elías Wessin y Wessin', 'Jorge Radhamés Zorrilla Ozuna', 'Aliança de Araújo', 'Manuel Carrascalão', 'Brigida Antónia Correia', 'Isabel da Costa Ferreira', 'Albina Marçal Freitas', 'Ángela Freitas', 'Justino Mota', 'Olinda Morais', 'Manuel Magalhaes de Oliveira', 'Alfredo Pires', 'Nino Konis Santana', 'José Abílio Osório Soares', 'João da Costa Tavares', 'Mário Viegas Carrascalão', 'Maria Terezinha Viegas', 'Luzmila Abad', 'Julio Martinez Acosta', 'Carlos Arizaga Toral', 'Aurora Estrada y Ayala', 'Fernando Balda', 'María Sol Corral', 'Jaime Durán Barba', 'Xavier Enderica', 'Isabel Enriquez', 'Ibeth Estupiñán', 'Guillermo Franco (Ecuadorian general)', 'Galo Lara', 'Andrea González Náder', 'Pablo Guerrero Martinez', 'Agustín Intriago', 'Jaminton Intriago', 'Roberto Izurieta', 'Marcel Jacobo Laniado de Wind', 'Luis A. Martínez', 'Pedro Moncayo', 'Mayra Montaño', 'Fabrizio Moreira', 'Diego Morejón', 'Catalina Ontaneda']
# Fetching information for batch: ['Johanna Ortiz', 'Mónica Palencia', 'Ismael Pérez Pazmiño', 'Filoteo Samaniego', 'Gabriela Sommerfeld', 'Arianna Tanca', 'Alfredo Vera Vera', 'Paola Vintimilla', 'Mariana Yumbay', 'Ahmad Pasha al-Munkali', 'Ahmed Issa (Egyptian politician)', 'Hamdi al-Sayyid', 'Mohsen Badawi', 'Abdelfattah al-Banna', 'Joseph Cattaui', 'Khaled Dawoud', 'Nabil Dibis', 'Ahmed Emad El-Din Radi', 'Sameh Seif El-Yazal', 'Ibrahim El-Gohary', 'Mamdouh Habib', 'Rafik Habib', 'Hisham Amna', 'Mohamed Ismail', 'Khaled Aly el-Bakly', 'Mostafa Madbouly', 'Mahmoud Ahmad Ibiary', 'Mahmoud Esmat', 'Mona Makram-Ebeid', 'Gawdat al-Malt', 'Ahmad Mazlum', 'George Messiha', 'Mohamed Maait', 'Mostafa Alnagar', 'Omar Marwan', 'Qatawi family', 'Diaa Rashwan', 'Talaat Sadat', 'Soares family', 'Soha Gendi', 'Youssef Zulficar Pasha', 'Abdullah Omran Taryam', 'Ahmed bin Mohammed Al Maktoum', 'Mohamed bin Hadi Al Hussaini', 'Hassan al Diqqi', 'Ahmed bin Rashid Al Maktoum', 'Ahmed bin Saeed Al Maktoum', 'Mohammed bin Khalifa Al Maktoum', 'Saeed bin Maktoum bin Hasher Al Maktoum', 'Hawaa Al Mansoori']
# Fetching information for batch: ['Mohammed bin Saud Al Qasimi', 'Hamed bin Zayed Al Nahyan', 'Khaled bin Mohamed Al Nahyan', 'Mohammed bin Khalifa bin Zayed Al Nahyan', 'Mohamed bin Zayed Al Nahyan', 'Saeed bin Zayed Al Nahyan', 'Saqr bin Zayed Al Nahyan', 'Shakhbut bin Sultan Al Nahyan', 'Mohammed Hussein Al Shaali', 'Abdulaziz Nasser Al Shamsi', 'Ahmad Al Tayer', 'Vice President of the United Arab Emirates', 'Felipe Hinestrosa Ikaka', 'Manuel Osa Nsue Nsua', 'Ahmed Mohammed Nasser', 'Ambaye Wolde Mariam', 'Girma Asmerom', 'Tedla Bairu', 'Hamid Ferej', 'Berhane Habtemariam', 'Habtezion Hadgu', 'Ibrahim Harun', 'Abraha Kassa', 'Abdulkadir Kebire', 'Abraham Kidane', 'Mohammed Saeed Nawed', 'Ibrahim Omer', 'Ali Radai', 'Romodan Mohammed Nur', 'Lehte Hainsalu', 'Carl Robert Jakobson', 'August Janson', 'Elmar Järvesoo', 'Harald Laksberg', 'Jüri Liim', 'Andi Meister', 'Friedrich Niggol', 'Andrei Prii', 'Theodor Rõuk', 'Toomas Sildmäe', 'Heino Sisask', 'Ants Tamme', 'Kirill Teiter', 'Georg Trašanov', 'Atnafu Abate', 'Abdirahman Eid Daahir', 'Mohamed Abdulghani', 'Abraham Tekeste', 'Agegnehu Teshager', 'Almayahu Haile']
# Fetching information for batch: ['Getachew Assefa', 'Habtamu Ayalew Teshome', 'Lake Ayalew', 'Saharla Abdulahi Bahdon', 'Juneidi Basha', 'Binalf Andualem', 'Mekdes Daba', 'Darge Sahle Selassie', 'Asrat Desta', 'Ergoge Tesfaye', 'Fitsum Assefa', 'Demelash Gebremichael', 'Alimirah Hanfare', 'Ibrahim Harun', 'Mawlid Hayir', 'Adem Ibrahim', 'Kemal Hashi Mohamoud', 'Kitaw Ejigu', 'Lencho Letta', 'Getahun Mekuria', 'Melatework Hailu', 'Mogus Wolde Mikael', 'Adem Mohammed', 'Jawar Mohammed', 'Belete Molla', 'Mulu Solomon', "Su'ad Ahmed Farah", 'Tadesse Birru', 'Frehiwot Tamiru', 'Taye Atskeselassie', 'Habtamu Tegegne', 'Tekle Wolde Hawaryat', 'Teklewold Atnafu', 'Temesgen Tiruneh', 'Tsegaye Mamo', 'Andargachew Tsege', 'Yilkal Kefale', 'Sophia Yilma', 'Erik Berg (politician)', 'Arthur Brofeldt', 'Anders Chydenius', 'Selim Ekbom', 'Simon Ekpa', 'Erik Fleming (councilor)', 'Klaus Fleming', 'Timo Furuholm', 'Jakob Gadolin', 'Mikhail Fyodorovich Ganskau', 'Carl Axel Gottlund', 'Lars Gabriel von Haartman']
# ...
# Fetching information for batch: ['André Hediger', "Heidi Z'graggen", 'Georg Friedrich Heilmann', 'Thomas Helbling', 'David Hess (painter)', 'Karl Otto Hunziker', 'Jakob Stark', 'Jean-Pierre Hocké', 'Walter Kälin', 'Thomas Knutti', 'Kris Vietze', 'Frédéric-César de La Harpe', 'Georgie Lamon', 'Hubert Lauper', 'Paul Lüönd', 'Martin Hübscher', 'Ursula Mauch', 'Jakob Meyer zum Hasen', 'Kurt Meyer (Lucerne)', 'Simon Michel', 'Damian Müller', 'Peter Ochs', 'Giovanni Orelli', 'Ludwig Pfyffer', 'Paul Rechsteiner', 'Rudolf Rechsteiner', 'Ital Reding the Elder', 'Jules Repond', 'Estelle Revaz', 'Gebhard Rohner', 'Eduard August Rübel', 'Farah Rumy', 'Vinzenz Rüttimann', 'Gregor Rutz', 'Sergio Salvioni', 'Alfred Emanuel Sarasin', 'Nicolas Théodore de Saussure', 'Peter-Josef Schallberger', 'Josef Scherrer', 'Jacob Schmidheiny', 'Nicola Siegrist', 'André Simonazzi', 'Vreni Spoerry', 'Niklaus Friedrich von Steiger', 'Silvia Steiner', 'Charles-Alexandre Steinhäuslin', 'Hansjörg Trachsel', 'Paul Usteri', 'Vroni Thalmann-Bieri', 'Eric Weber']
# Fetching information for batch: ['Johann Rudolf Wettstein', 'Louis Wyrsch', 'Theodor Ab Yberg', 'Andrea Zryd', 'Sebastian Peregrin Zwyer', 'Ursula Zybach', 'Adil Arslan', 'Mohammed Akkad', 'Sultan al-Atrash', 'Ayyash Al-Haj', 'Ghias Barakat', 'Subhi Bey Barakat', 'Abdul Qader Barmada', 'Tawfiq Bay', 'Ibrahim Biro', 'Yusuf Franko Coussa', 'Amir al-Dandal', 'Abd al-Razzaq al-Dandashi', 'Ahmad Diyab', "Hadad-yith'i", 'Hisham Marwah', 'Edmond Al-Homsi', 'Louay Hussein', 'Ihsan Al Jabri', 'Jihad Makdissi', 'Mohammad Jumah', 'Sami al-Jundi', 'Kamal al-Qassab', 'Kamil Pasha al-Qudsi', 'Abdul-Aziz al-Khair', 'Fayez al-Khoury', "Mar'i Pasha al-Mallah", 'Hrant Maloyan', 'Antun Maqdisi', 'Mahmoud Ahmad Marei', 'Muhammad Talab Hilal', 'Mustafa al-Mousa', "Mustafa al-Siba'i", 'Shukri al-Quwatli', 'Nasim al-Safarjalani', 'Salem al-Meslet', 'Muhammad al-Sufi', 'Mohammad Farouk Tayfour', 'Huang Chaoqin', 'Li Huang', 'Lin Tze-luen', 'Liu Yongfu', 'Chiu Feng-chia', 'Jay N. Shih', 'Wu Fang-ming']
# Fetching information for batch: ['Ravshanbek Qurbonov', 'Baxtiyor Rahimov', 'Bekjon Rakhmonov', 'Bakhodir Khan Turkistan', 'Qobul Tursunov', 'Vincent Lunabek', 'President of Vanuatu', 'Jimmy Stevens (politician)', 'Dinh Van Than', 'Fernando Adames Torres', 'Ivonne Attas', 'Fidel Barbarito', 'Pedro Bastidas', 'Alejandra Benítez', 'José Brito (politician)', 'Buenaventura Macabeo Maldonado Vivas', 'Rubén González Cárdenas', 'José Curiel', 'Felix Díaz Ortega', 'Vicente José Gregorio Díaz Silva', 'Alí Domínguez', 'Franklyn Duarte', 'Alberto Franceschi', 'Arnoldo Gabaldón', 'Vladimir Gessen (Venezuelan politician)', 'Jorge Giordani', 'César González Martínez', 'Luis Graterol Caraballo', 'Liborio Guarulla', 'José Bernabé Gutiérrez', 'María Cristina Iglesias', 'Reinaldo Iturriza', 'Andrés Izarra', 'Reinaldo Leandro Mora', 'Carlos Augusto León', 'Ramón Lobo (economist)', 'Jorge Elieser Márquez', 'Américo Martín', 'Nelson Martínez (politician)', 'Francisco de Miranda', 'Reinaldo Muñoz Pedroza', 'Dia Nader de El-Andari', 'Moisés Naím', 'Freddy Ñáñez', 'Pablo Acosta Ortiz', 'Renny Ottolina', 'Alejandro Peña Esclusa', 'Miguel Peña (politician)', 'Lewis Pérez', 'Arkiely Perfecto']
# Fetching information for batch: ['Eduardo Piñate', 'Humberto Prado', 'Omar Prieto', 'Benjamín Rausseo', 'Manuel Felipe Rugeles', 'Carlos Santana Tovar', 'Milena Sardi de Selle', 'Carlos Eduardo Stolk', 'Bolivia Suárez', 'Gustavo Tarre', 'José Herrera Uslar', 'Addy Valero', 'José Antonio Velutini', 'Henry Ventura', 'Nervis Villalobos', 'Bùi Tiến Dũng (politician)', 'Chu Văn An', 'Nguyễn Quốc Định', 'Đinh Xuân Quảng', 'Kiem Do', 'Đỗ Quang Giai', 'Hồ Đắc Điềm', 'Hồ Văn Nhựt', 'Hoàng Cao Khải', 'Hoang Van Chi', 'Huỳnh Văn Cao', 'Kiều Mộng Thu', 'Lê Minh Hương', 'Lê Quốc Minh', 'Lê Văn Thành', 'Lương Thế Huy', 'Nguyễn Hồng Diên', 'Nguyễn Đức Chung', 'Nguyễn Dương Đôn', 'Nguyễn Duy Quý', 'Nguyễn Hợp Đoàn', 'Nguyễn Phan Long', 'Nguyễn Quốc Cường', 'Nguyễn Thị Hồng (economist)', 'Nguyễn Thị Thập', 'Nguyễn Văn Huyền', 'Nguyễn Văn Lực', 'Nguyễn Văn Trân', 'Nguyễn Văn Xuân', 'Phan Anh', 'Tạ Quang Bửu', 'Tran Minh Tiet', 'Trần Quốc Vượng (politician)', 'Trần Văn Hữu', 'Trương Đình Dzu']
# Fetching information for batch: ['Võ Văn Thưởng', 'Abdullah Noman', 'Hashid Abdullah al-Ahmar', 'Himyar Abdullah al-Ahmar', 'Sam Yahya Al-Ahmar', 'Ameen Ali al-Akimi', 'Talal Aklan', 'Abdullatif Al-Sayed', 'Muhammad Musa al-Amri', 'Mohamed al-Atifi', 'Yasser Al-Awadi', 'Sagheer Hamoud Aziz', 'Sultan al-Barakani', 'Faraj Salmin Al-Bahsani', 'Ali Al Bukhaiti', 'Bruce Conde', 'Abdul Wahab Al-Dailami', 'Ali Ahmad Nasser al-Dhahab', 'Badreddin al-Houthi', 'Ibrahim Bin Ali Al Wazeer', 'Mohammed Lutf al-Iryani', 'Abd Al-Rahman Ali Al-Jifri', 'Hussein Khairan', 'Mohammed Ali Al-Maqdashi', 'Hooria Mashhour', 'Muhammad bin Yahya bin Muhammad', 'Abdul Qader Qahtan', 'Abdulwahab al-Rawhani', 'Mohammed al-Sabry', 'Yahya Mohamed Abdullah Saleh', 'Ali Taysir', 'Yahya Muhammad Hamid ed-Din', 'Aidarus al-Zoubaidi', 'Francis Kapyanga', 'Lily Monze', 'Olipa Phiri', 'Gift Banda', 'Flora Buka', 'Bulelani Lobengula', 'Joseph Makamba Busha', 'Darlington Dzikamai Chigumbu', 'James Chikerema', 'Paul Chimedza', 'Chenhamo Chimutengwende', 'Ruth Chinamano', 'George Chiweshe', 'Phillip Chiyangwa', 'Guy Clutton-Brock', 'Margaret Dongo', 'Jabulani Dube']
# Fetching information for batch: ['Fletcher Dulini Ncube', 'Ken Flower', 'Aguy Georgias', 'Sithembile Gumbo', 'Josiah Zion Gumede', 'Ellen Gwaradzimba', 'Andre Sothern Holland', 'Byron Hove', 'Tonderai Kasu', 'Wilson Khumbula', 'Lovemore Madhuku', 'Sarah Mahoka', 'Alfred Makwarimba', 'Washington Malianga', 'Elliot Manyika', 'Linda Masarira', 'Jevan Maseko', 'Anxious Masuka', 'Lovemore Matombo', 'Bright Matonga', 'Isaac Matongo', 'Obedingwa Mguni', 'Promise Mkwananzi', 'Max Mnkandla', 'Bekithemba Mpofu', 'Earnest Mudzengi', 'Mugabe family', 'Kisinoti Mukwazhe', 'Edwin Mushoriwa', 'Munacho Mutezo', 'Abel Muzorewa', 'Prag Lalloo Naran', 'Owen Ncube', 'Nhlanhlayamangwe Felix Ndiweni', 'Gundwane Ndiweni', 'Khayisa Ndiweni', 'Jane Ngwenya', 'Maurice Nyagumbo', 'George Nyandoro', 'Sekai Nzenza', 'Engelbert Rugeje', 'Tinos Rusere', 'Scot Sakupwanya', 'Daniel Shumba', 'Maxwell Zeb Shumba', 'Nkululeko Mkastos Sibanda', 'Leopold Takawira', 'Gift Tandare', 'Rekayi Tangwena', 'Temba Mliswa']
# Fetching information for batch: ['Josiah Tongogara', 'Langton Towungana', 'Sengezo Tshabangu', 'Herbert Ushewokunze', 'Denis Walker']
# Data successfully saved to articles_page_info.json.

# %% [markdown]
# The number of articles for which we could successfully get the API information were 7103.
#
# The next step takes about 2-2.5 hours to run. I have already run this step, and the corresponding csv has been saved in a file named articles_ores_score.csv under the intermediary_files folder. Skip the next cells to proceed the analysis using the already fetched data.

# %%
#    Make the call, just pass in the article revision ID, email address, and access token
json_file_path = '.intermediary_files/articles_page_info.json'
# Requesting ORES score for revision ID: 1246276309
# Requesting ORES score for revision ID: 1199625809
# Requesting ORES score for revision ID: 1084850620
# Requesting ORES score for revision ID: 1230504811
# Requesting ORES score for revision ID: 1246135863
# Requesting ORES score for revision ID: 1226322430
# Requesting ORES score for revision ID: 1108499694
# Requesting ORES score for revision ID: 1236900271
# Requesting ORES score for revision ID: 1177290618
# Requesting ORES score for revision ID: 1138179170
# Requesting ORES score for revision ID: 1105192324
# Requesting ORES score for revision ID: 1225102400
# Requesting ORES score for revision ID: 1007344798
# Requesting ORES score for revision ID: 1246242430
# Requesting ORES score for revision ID: 1245786617
# Requesting ORES score for revision ID: 1112725980
# Requesting ORES score for revision ID: 1193170496
# Requesting ORES score for revision ID: 1243016866
# Requesting ORES score for revision ID: 1247645001
# Requesting ORES score for revision ID: 1246242012
# Requesting ORES score for revision ID: 1170189291
# Requesting ORES score for revision ID: 1246747822
# Requesting ORES score for revision ID: 1236117496
# Requesting ORES score for revision ID: 1246239576
# Requesting ORES score for revision ID: 1242611251
# Requesting ORES score for revision ID: 1241843269
# Requesting ORES score for revision ID: 1246239507
# Requesting ORES score for revision ID: 1246241769
# Requesting ORES score for revision ID: 1236282175
# Requesting ORES score for revision ID: 1231961724
# Requesting ORES score for revision ID: 1064532257
# Requesting ORES score for revision ID: 1246239559
# Requesting ORES score for revision ID: 1247902630
# Requesting ORES score for revision ID: 959111842
# Requesting ORES score for revision ID: 1203429435
# Requesting ORES score for revision ID: 1246280093
# Requesting ORES score for revision ID: 1228478288
# Scores saved to intermediary_files/articles_ores_scores.csv

# %% [markdown]
# # Step 3: Combining the Datasets
#
# We need to combine the revision id json with the csv file with ores score to generate a final csv which we will use for further analysis. Which will then be merged with the population csv.

# %%
def create_final_dataframe(json_file_path, csv_file_path, source_data_file_path):
    """
    Create a final DataFrame by merging politician data from a JSON file with scores from a CSV file.

    Args:
        json_file_path (str): Path to the JSON file containing politician data.
        csv_file_path (str): Path to the CSV file containing ORES scores.
        source_data_csv (str): Path to source data about the politician artciles
    """
    
    # Load JSON data
    with open(json_file_path, 'r', encoding='utf-8') as json_file:
        politicians_data = json.load(json_file)

    source_data_df = pd.read_csv(source_data_file_path)
    
    # Convert JSON data to DataFrame
    df_article_info = pd.DataFrame.from_dict(politicians_data, orient='index')

    merged_df_join_with_source = pd.merge(source_data_df, df_article_info, left_on='name', right_on='title', how='left')

    # Load CSV data
    ores_scores_df = pd.read_csv(csv_file_path)

    # Perform inner join on different column names
    merged_df_source_with_scores = pd.merge(merged_df_join_with_source, ores_scores_df, left_on='lastrevid', right_on='revision_id', how='left')
    merged_df_source_with_scores = merged_df_source_with_scores[['name', 'country', 'pageid', 'title', 'revision_id', 'quality_prediction']]
    merged_df_source_with_scores["revision_id"] = merged_df_source_with_scores["revision_id"].astype("Int64")

    return merged_df_source_with_scores

    # Save final DataFrame to CSV
    # final_df.to_csv(output_csv_path, index=False)
    # print(f"Final DataFrame saved to {output_csv_path}")
# Example usage
final_df_source_with_scores = create_final_dataframe(
    json_file_path='intermediary_files/articles_page_info.json',
    csv_file_path='intermediary_files/articles_ores_scores.csv',
    source_data_file_path= 'politicians_by_country_AUG.2024.csv'
)

final_df_source_with_scores
# Out:
#                       name      country      pageid                 title  \
# 0           Majah Ha Adrif  Afghanistan  10483286.0        Majah Ha Adrif
# 1        Haroon al-Afghani  Afghanistan  11966231.0     Haroon al-Afghani
# 2              Tayyab Agha  Afghanistan  46841383.0           Tayyab Agha
# 3     Khadija Zahra Ahmadi  Afghanistan  71600382.0  Khadija Zahra Ahmadi
# 4           Aziza Ahmadyar  Afghanistan  47805901.0        Aziza Ahmadyar
# ...                    ...          ...         ...                   ...
# 7150      Josiah Tongogara     Zimbabwe    633594.0      Josiah Tongogara
# 7151     Langton Towungana     Zimbabwe  16375315.0     Langton Towungana
# 7152     Sengezo Tshabangu     Zimbabwe  75270547.0     Sengezo Tshabangu
# 7153   Herbert Ushewokunze     Zimbabwe  11742819.0   Herbert Ushewokunze
# 7154          Denis Walker     Zimbabwe   3255571.0          Denis Walker
#
#       revision_id quality_prediction
# 0      1233202991              Start
# 1      1230459615                  B
# 2      1225661708              Start
# 3      1234741562               Stub
# 4      1195651393              Start
# ...           ...                ...
# 7150   1203429435                  C
# 7151   1246280093               Stub
# 7152   1228478288              Start
# 7153    959111842               Stub
# 7154   1247902630                  C
#
# [7155 rows x 6 columns]

# %% [markdown]
# Analysing aquired data: Now we have a list of politicians' wiki articles along with their revision_id, page_id and article_rating. For articles where ORES call failed, we will have a row in the list where article rating is set to empty.

# %%
# Wikilist politician articles with no revision_id => pageInfo call failed
missing_revision_id_df = final_df_source_with_scores[final_df_source_with_scores["revision_id"].isna()]
print("Total number of articles for which pageInfo call failed: " , missing_revision_id_df.shape[0])
missing_revision_id_df
# Out:
# Total number of articles for which pageInfo call failed:  8
#                             name             country  pageid  \
# 430       Barbara Eibinger-Miedl             Austria     NaN
# 516              Mehrali Gasimov          Azerbaijan     NaN
# 1200                  Kyaw Myint             Myanmar     NaN
# 1342      André Ngongang Ouandji            Cameroon     NaN
# 1955              Tomás Pimentel  Dominican Republic     NaN
# 2427               Richard Sumah               Ghana     NaN
# 4496  Segun ''Aeroland'' Adewale             Nigeria     NaN
# 5719             Bashir Bililiqo             Somalia     NaN
#
#                            title  revision_id quality_prediction
# 430       Barbara Eibinger-Miedl         <NA>                NaN
# 516              Mehrali Gasimov         <NA>                NaN
# 1200                  Kyaw Myint         <NA>                NaN
# 1342      André Ngongang Ouandji         <NA>                NaN
# 1955              Tomás Pimentel         <NA>                NaN
# 2427               Richard Sumah         <NA>                NaN
# 4496  Segun ''Aeroland'' Adewale         <NA>                NaN
# 5719             Bashir Bililiqo         <NA>                NaN

# %%
having_revision_id_df = final_df_source_with_scores[~final_df_source_with_scores["revision_id"].isna()]
print("Total number of articles for which pageInfo call succeeded: " , having_revision_id_df.shape[0])

having_rating_df = final_df_source_with_scores[~final_df_source_with_scores["quality_prediction"].isna()]
print("Total number of articles for which pageInfo call succeeded, and ORES API call succeesed: " , having_rating_df.shape[0])
# Out:
# Total number of articles for which pageInfo call succeeded:  7147
# Total number of articles for which pageInfo call succeeded, and ORES API call succeesed:  7135

# %% [markdown]
# Adding population and region details
#
# At this stage, we have the initial list of artiles provided with data about latest revision id and article rating. We now want to enrich the list even further by adding details about the population and region of the country associated to the article title.
#
# We now find which country belongs to which region. As we know the regions and countries are in a hierarchical order.

# %%
# Load the population CSV into a DataFrame
population_df = pd.read_csv('./population_by_country_AUG.2024.csv')

# Loop through each row in the dataframe. If name is all capital letters, means it is a region.
region = ""

population_list = []

for index, row in population_df.iterrows():
    row_dict = row.to_dict()
    if row["Geography"].isupper():
        # save the geography in a variable
        region = row["Geography"]
        region_population = row["Population"]
        row_dict["region"] = ""
    else:
        # assign the region to the latest value in the region variable
        row_dict["region"] = region

    population_list.append(row_dict)

population_df_regions = pd.DataFrame(population_list)
population_df_regions = population_df_regions.rename(columns = {"Geography": "country", "Population": "population"})
country_region_df = population_df_regions[~population_df_regions["country"].str.isupper()].reset_index(drop=True)
print("Total number of countries in the `population_by_country_AUG.2024.csv` : ", country_region_df.shape[0])
 
country_region_df
# Out:
# Total number of countries in the `population_by_country_AUG.2024.csv` :  209
#              country  population           region
# 0            Algeria        46.8  NORTHERN AFRICA
# 1              Egypt       105.2  NORTHERN AFRICA
# 2              Libya         6.9  NORTHERN AFRICA
# 3            Morocco        37.0  NORTHERN AFRICA
# 4              Sudan        48.1  NORTHERN AFRICA
# ..               ...         ...              ...
# 204            Samoa         0.2          OCEANIA
# 205  Solomon Islands         0.8          OCEANIA
# 206            Tonga         0.1          OCEANIA
# 207           Tuvalu         0.0          OCEANIA
# 208          Vanuatu         0.3          OCEANIA
#
# [209 rows x 3 columns]

# %% [markdown]
# ### Merging datasets
#
# At this stage, we have two datasets:
#
# 1. A list of Wikipedia articles about politicians, containing details such as the politician's country, article revision ID, and article title.
# 2. A list of countries with information on population and their respective regions.
#
# We aim to merge these datasets for the next steps in our analysis, to determine the number of articles, particularly high-quality ones, per capita, both country-wise and region-wise.

# %%
# Merging the data frames of interest using outer join to find the mismatched countries.
article_scores_with_country = pd.merge(final_df_source_with_scores, country_region_df, on=["country"], how="outer", indicator=True)
article_scores_with_country
# Out:
#                       name      country      pageid                 title  \
# 0           Majah Ha Adrif  Afghanistan  10483286.0        Majah Ha Adrif
# 1        Haroon al-Afghani  Afghanistan  11966231.0     Haroon al-Afghani
# 2              Tayyab Agha  Afghanistan  46841383.0           Tayyab Agha
# 3     Khadija Zahra Ahmadi  Afghanistan  71600382.0  Khadija Zahra Ahmadi
# 4           Aziza Ahmadyar  Afghanistan  47805901.0        Aziza Ahmadyar
# ...                    ...          ...         ...                   ...
# 7193     Langton Towungana     Zimbabwe  16375315.0     Langton Towungana
# 7194     Sengezo Tshabangu     Zimbabwe  75270547.0     Sengezo Tshabangu
# 7195   Herbert Ushewokunze     Zimbabwe  11742819.0   Herbert Ushewokunze
# 7196          Denis Walker     Zimbabwe   3255571.0          Denis Walker
# 7197                   NaN     eSwatini         NaN                   NaN
#
#       revision_id quality_prediction  population           region      _merge
# 0      1233202991              Start        42.4       SOUTH ASIA        both
# 1      1230459615                  B        42.4       SOUTH ASIA        both
# 2      1225661708              Start        42.4       SOUTH ASIA        both
# 3      1234741562               Stub        42.4       SOUTH ASIA        both
# 4      1195651393              Start        42.4       SOUTH ASIA        both
# ...           ...                ...         ...              ...         ...
# 7193   1246280093               Stub        16.7   EASTERN AFRICA        both
# 7194   1228478288              Start        16.7   EASTERN AFRICA        both
# 7195    959111842               Stub        16.7   EASTERN AFRICA        both
# 7196   1247902630                  C        16.7   EASTERN AFRICA        both
# 7197         <NA>                NaN         1.2  SOUTHERN AFRICA  right_only
#
# [7198 rows x 9 columns]

# %% [markdown]
# We see that there are countries which do not have any articles associated as well as articles which do not have a country associated. To find a list of countries which do not have this match we look at the '_merge' column in the above dataframe and filter out the rows with values other than 'both' and get only the unique country names.

# %%
output_no_match_path='./result_files/wp_countries-no_match.txt'
output_consolidated_path='./result_files/wp_politicians_by_country.csv'

# Identify unmatched countries
unmatched_df = article_scores_with_country[article_scores_with_country['_merge'] != 'both']

# Extract unique unmatched countries
unmatched_countries = unmatched_df['country'].dropna().unique()

# Save unmatched countries to a text file
with open(output_no_match_path, 'w') as f:
    for country in unmatched_countries:
        f.write(f"{country}\n")

print(f"Unmatched countries saved to {output_no_match_path}")

# Consolidate remaining matched data into a single CSV
consolidated_df = article_scores_with_country[article_scores_with_country['_merge'] == 'both']
wp_politicians_by_country = consolidated_df.drop(columns = [  "_merge"], axis=1)
wp_politicians_by_country = wp_politicians_by_country.rename(columns = { "quality_prediction": "article_quality"})
wp_politicians_by_country = wp_politicians_by_country[["country", "region", "population", "title", "revision_id", "article_quality"]]
wp_politicians_by_country = wp_politicians_by_country.drop_duplicates()
wp_politicians_by_country
# Out:
# Unmatched countries saved to ./result_files/wp_countries-no_match.txt
#           country          region  population                 title  \
# 0     Afghanistan      SOUTH ASIA        42.4        Majah Ha Adrif
# 1     Afghanistan      SOUTH ASIA        42.4     Haroon al-Afghani
# 2     Afghanistan      SOUTH ASIA        42.4           Tayyab Agha
# 3     Afghanistan      SOUTH ASIA        42.4  Khadija Zahra Ahmadi
# 4     Afghanistan      SOUTH ASIA        42.4        Aziza Ahmadyar
# ...           ...             ...         ...                   ...
# 7192     Zimbabwe  EASTERN AFRICA        16.7      Josiah Tongogara
# 7193     Zimbabwe  EASTERN AFRICA        16.7     Langton Towungana
# 7194     Zimbabwe  EASTERN AFRICA        16.7     Sengezo Tshabangu
# 7195     Zimbabwe  EASTERN AFRICA        16.7   Herbert Ushewokunze
# 7196     Zimbabwe  EASTERN AFRICA        16.7          Denis Walker
#
#       revision_id article_quality
# 0      1233202991           Start
# 1      1230459615               B
# 2      1225661708           Start
# 3      1234741562            Stub
# 4      1195651393           Start
# ...           ...             ...
# 7192   1203429435               C
# 7193   1246280093            Stub
# 7194   1228478288           Start
# 7195    959111842            Stub
# 7196   1247902630               C
#
# [7013 rows x 6 columns]

# %%
print("unmatched countries:" ,unmatched_countries)
# Out:
# unmatched countries: ['Andorra' 'Australia' 'Brunei' 'Canada' 'China (Hong Kong SAR)'
#  'China (Macao SAR)' 'Curacao' 'Denmark' 'Dominica' 'Fiji' 'French Guiana'
#  'French Polynesia' 'Georgia' 'Guadeloupe' 'Guam' 'Guinea-Bissau'
#  'GuineaBissau' 'Iceland' 'Ireland' 'Jamaica' 'Kiribati' 'Korea (North)'
#  'Korea (South)' 'Korea, South' 'Korean' 'Liechtenstein' 'Martinique'
#  'Mauritius' 'Mayotte' 'Mexico' 'Nauru' 'Netherlands' 'New Caledonia'
#  'New Zealand' 'Palau' 'Philippines' 'Puerto Rico' 'Reunion' 'Romania'
#  'San Marino' 'Sao Tome and Principe' 'Suriname' 'United Kingdom'
#  'United States' 'Western Sahara' 'eSwatini']

# %%
# Write the dataframe to a file
wp_politicians_by_country.to_csv("result_files/wp_politicians_by_country.csv", index=False)

# %% [markdown]
# # Step 4: Analysis and results
#
# This analysis involves calculating two key metrics on both a country-by-country and regional basis:
#
# 1. **Total Articles per Capita**: The ratio of the number of articles to the population of each country or region.
# 2. **High-Quality Articles per Capita**: The ratio of high-quality articles (classified as "FA" for Featured Article or "GA" for Good Article by ORES) to the population of each country or region.
#
# ### Key Considerations:
# - Each country is assigned to only one region, and the `population_by_country_AUG.2024.csv` file represents regions in a hierarchical structure. In the analysis, ensure that each country is placed in the closest, most specific (lowest in the hierarchy) region.
# - The population data in `population_by_country_AUG.2024.csv` is provided in millions, so the calculated ratios may result in very small values. Careful thought should be given to how the results are represented to ensure clarity.
#
# ### Steps Done in the Code:
# - Calculated the total number of articles per capita and high-quality articles per capita, both at the country level and the regional level.
# - Ensured that countries were correctly assigned to their closest hierarchical region based on the dataset.
# - Applied filtering to classify articles as high-quality if ORES predicted them as either "FA" (Featured Article) or "GA" (Good Article).
# - Adjusted the representation of results, given that population data is in millions and the resulting ratios are very small.

# %%
# Grouping data by country, region, and population to count total articles
article_count_by_country = wp_politicians_by_country.groupby(
    ['country', 'region', 'population']
).size().reset_index(name='total_articles')

# Filter out rows where population is 0 for the calculation
article_count_by_country = article_count_by_country.loc[article_count_by_country['population'] > 0]

# Calculating total articles per capita
article_count_by_country["articles_per_capita"] = article_count_by_country["total_articles"] / article_count_by_country["population"]

# Sorting and selecting the top 10 countries with the highest articles per capita
top_10_countries = article_count_by_country.sort_values("articles_per_capita", ascending=False).reset_index(drop=True)
top_10_countries = top_10_countries.head(10)

# Displaying the result
print("The 10 countries with the highest total articles per capita (in descending order):")
top_10_countries
# Out:
# The 10 countries with the highest total articles per capita (in descending order):
#                           country           region  population  \
# 0             Antigua and Barbuda        CARIBBEAN         0.1
# 1  Federated States of Micronesia          OCEANIA         0.1
# 2                Marshall Islands          OCEANIA         0.1
# 3                           Tonga          OCEANIA         0.1
# 4                        Barbados        CARIBBEAN         0.3
# 5                      Seychelles   EASTERN AFRICA         0.1
# 6                      Montenegro  SOUTHERN EUROPE         0.6
# 7                          Bhutan       SOUTH ASIA         0.8
# 8                        Maldives       SOUTH ASIA         0.6
# 9                           Samoa          OCEANIA         0.2
#
#    total_articles  articles_per_capita
# 0              33           330.000000
# 1              14           140.000000
# 2              13           130.000000
# 3              10           100.000000
# 4              25            83.333333
# 5               6            60.000000
# 6              36            60.000000
# 7              44            55.000000
# 8              33            55.000000
# 9               8            40.000000

# %% [markdown]
# The total articles per capita for countries like Monaco and Tuvalu comes out to be inf because the population data we have for these countries is 0 therefore I decided to remove them from the calculation.

# %%
# Bottom 10 countries by coverage: The 10 countries with the lowest total articles per capita (in ascending order) .
# Sorting and selecting the bottom 10 countries with the highest articles per capita
bottom_10_countries = article_count_by_country.sort_values("articles_per_capita", ascending=True).reset_index(drop=True)
bottom_10_countries = bottom_10_countries.head(10)

# Displaying the result
print("The 10 countries with the highest total articles per capita (in ascending order):")
bottom_10_countries
# Out:
# The 10 countries with the highest total articles per capita (in ascending order):
#          country           region  population  total_articles  \
# 0          China        EAST ASIA      1411.3              16
# 1          India       SOUTH ASIA      1428.6             151
# 2          Ghana   WESTERN AFRICA        34.1               4
# 3   Saudi Arabia     WESTERN ASIA        36.9               5
# 4         Zambia   EASTERN AFRICA        20.2               3
# 5         Norway  NORTHERN EUROPE         5.5               1
# 6         Israel     WESTERN ASIA         9.8               2
# 7          Egypt  NORTHERN AFRICA       105.2              32
# 8  Cote d'Ivoire   WESTERN AFRICA        30.9              10
# 9       Ethiopia   EASTERN AFRICA       126.5              44
#
#    articles_per_capita
# 0             0.011337
# 1             0.105698
# 2             0.117302
# 3             0.135501
# 4             0.148515
# 5             0.181818
# 6             0.204082
# 7             0.304183
# 8             0.323625
# 9             0.347826

# %% [markdown]
# An article is considered high quality if it has an FA or GA ratings. So we will filter out articles with top rating and then display the top 10 countries which have the high quality articles.

# %%
# Top 10 countries by high quality: The 10 countries with the highest high quality articles per capita (in descending order)

high_quality_articles = wp_politicians_by_country[wp_politicians_by_country["article_quality"].isin(["FA", "GA"])]
high_quality_articles_count = high_quality_articles.groupby(['country', 'region', 'population']).size().reset_index(name='total_articles')
high_quality_articles_count["total_articles_per_capita"] = high_quality_articles_count["total_articles"] / high_quality_articles_count["population"]

top_10 = high_quality_articles_count.sort_values("total_articles_per_capita", ascending=False).reset_index(drop=True)
top_10 = top_10.head(10)

print("The 10 countries with the highest high quality articles per capita (in descending order):")
top_10
# Out:
# The 10 countries with the highest high quality articles per capita (in descending order):
#                  country           region  population  total_articles  \
# 0             Montenegro  SOUTHERN EUROPE         0.6               3
# 1             Luxembourg   WESTERN EUROPE         0.7               2
# 2                Albania  SOUTHERN EUROPE         2.7               7
# 3                 Kosovo  SOUTHERN EUROPE         1.7               4
# 4               Maldives       SOUTH ASIA         0.6               1
# 5              Lithuania  NORTHERN EUROPE         2.9               4
# 6                Croatia  SOUTHERN EUROPE         3.8               5
# 7                 Guyana    SOUTH AMERICA         0.8               1
# 8  Palestinian Territory     WESTERN ASIA         5.5               6
# 9               Slovenia  SOUTHERN EUROPE         2.1               2
#
#    total_articles_per_capita
# 0                   5.000000
# 1                   2.857143
# 2                   2.592593
# 3                   2.352941
# 4                   1.666667
# 5                   1.379310
# 6                   1.315789
# 7                   1.250000
# 8                   1.090909
# 9                   0.952381

# %%
# Bottom 10 countries by high quality: The 10 countries with the lowest high quality articles per capita (in ascending order).
bottom_10 = high_quality_articles_count.sort_values("total_articles_per_capita", ascending=True).reset_index(drop=True)
bottom_10 = bottom_10.head(10)

print("The 10 countries with the least high quality articles per capita (in ascending order):")
bottom_10
# Out:
# The 10 countries with the least high quality articles per capita (in ascending order):
#       country           region  population  total_articles  \
# 0  Bangladesh       SOUTH ASIA       173.5               1
# 1       Egypt  NORTHERN AFRICA       105.2               1
# 2    Ethiopia   EASTERN AFRICA       126.5               2
# 3       Japan        EAST ASIA       124.5               2
# 4    Pakistan       SOUTH ASIA       240.5               4
# 5    Colombia    SOUTH AMERICA        52.2               1
# 6    Congo DR    MIDDLE AFRICA       102.3               2
# 7     Vietnam   SOUTHEAST ASIA        98.9               2
# 8      Uganda   EASTERN AFRICA        48.6               1
# 9     Algeria  NORTHERN AFRICA        46.8               1
#
#    total_articles_per_capita
# 0                   0.005764
# 1                   0.009506
# 2                   0.015810
# 3                   0.016064
# 4                   0.016632
# 5                   0.019157
# 6                   0.019550
# 7                   0.020222
# 8                   0.020576
# 9                   0.021368

# %%
# Geographic regions by total coverage: A rank ordered list of geographic regions (in descending order) by total articles per capita.

articles_count_per_region = wp_politicians_by_country.groupby(['region']).size().reset_index(name='total_articles')
articles_count_per_region
# Out:
#              region  total_articles
# 0         CARIBBEAN             219
# 1   CENTRAL AMERICA             188
# 2      CENTRAL ASIA             106
# 3         EAST ASIA             152
# 4    EASTERN AFRICA             665
# 5    EASTERN EUROPE             709
# 6     MIDDLE AFRICA             231
# 7   NORTHERN AFRICA             302
# 8   NORTHERN EUROPE             191
# 9           OCEANIA              72
# 10    SOUTH AMERICA             569
# 11       SOUTH ASIA             670
# 12   SOUTHEAST ASIA             396
# 13  SOUTHERN AFRICA             123
# 14  SOUTHERN EUROPE             797
# 15   WESTERN AFRICA             515
# 16     WESTERN ASIA             610
# 17   WESTERN EUROPE             498

# %%
# Merging article counts with population data based on region
merged_regional_data = pd.merge(
    articles_count_per_region[['region', 'total_articles']],
    population_df[['Geography', 'Population']],
    left_on="region", right_on="Geography", how="left"
)

# Calculating total articles per capita for each region
merged_regional_data["articles_per_capita"] = merged_regional_data["total_articles"] / merged_regional_data["Population"]

# Sorting the data by articles per capita in descending order and resetting the index
sorted_regional_data = merged_regional_data.sort_values("articles_per_capita", ascending=False).reset_index(drop=True)

# Displaying the sorted data
sorted_regional_data[["region", "total_articles", "Population", "articles_per_capita"]]
# Out:
#              region  total_articles  Population  articles_per_capita
# 0   SOUTHERN EUROPE             797       152.0             5.243421
# 1         CARIBBEAN             219        44.0             4.977273
# 2    WESTERN EUROPE             498       199.0             2.502513
# 3    EASTERN EUROPE             709       285.0             2.487719
# 4      WESTERN ASIA             610       299.0             2.040134
# 5   NORTHERN EUROPE             191       108.0             1.768519
# 6   SOUTHERN AFRICA             123        70.0             1.757143
# 7           OCEANIA              72        45.0             1.600000
# 8    EASTERN AFRICA             665       483.0             1.376812
# 9     SOUTH AMERICA             569       426.0             1.335681
# 10     CENTRAL ASIA             106        80.0             1.325000
# 11  NORTHERN AFRICA             302       256.0             1.179688
# 12   WESTERN AFRICA             515       442.0             1.165158
# 13    MIDDLE AFRICA             231       202.0             1.143564
# 14  CENTRAL AMERICA             188       182.0             1.032967
# 15   SOUTHEAST ASIA             396       682.0             0.580645
# 16       SOUTH ASIA             670      2029.0             0.330212
# 17        EAST ASIA             152      1648.0             0.092233

# %%
# Geographic regions by high quality coverage: Rank ordered list of geographic regions (in descending order) by high quality articles per capita.
hq_articles_count_per_region = high_quality_articles.groupby(['region']).size().reset_index(name='total_articles')
hq_articles_count_per_region
# Out:
#              region  total_articles
# 0         CARIBBEAN               9
# 1   CENTRAL AMERICA              10
# 2      CENTRAL ASIA               5
# 3         EAST ASIA               3
# 4    EASTERN AFRICA              17
# 5    EASTERN EUROPE              38
# 6     MIDDLE AFRICA               8
# 7   NORTHERN AFRICA              16
# 8   NORTHERN EUROPE               9
# 9           OCEANIA               1
# 10    SOUTH AMERICA              19
# 11       SOUTH ASIA              21
# 12   SOUTHEAST ASIA              25
# 13  SOUTHERN AFRICA               8
# 14  SOUTHERN EUROPE              53
# 15   WESTERN AFRICA              13
# 16     WESTERN ASIA              27
# 17   WESTERN EUROPE              21

# %%
# Merging high-quality articles count data with population data based on region
hq_regional_data = pd.merge(
    hq_articles_count_per_region,  
    population_df,  
    left_on=["region"],  
    right_on=["Geography"],  
    how="left"  
)

# Selecting only relevant columns: region, total articles, and population
hq_regional_data = hq_regional_data[["region", "total_articles", "Population"]]

# Calculating total high-quality articles per capita
hq_regional_data["total_articles_per_capita"] = hq_regional_data["total_articles"] / hq_regional_data["Population"]

# Sorting the regions by total high-quality articles per capita in descending order
hq_regional_data = hq_regional_data.sort_values("total_articles_per_capita", ascending=False).reset_index(drop=True)

# Displaying the final sorted dataframe
hq_regional_data
# Out:
#              region  total_articles  Population  total_articles_per_capita
# 0   SOUTHERN EUROPE              53       152.0                   0.348684
# 1         CARIBBEAN               9        44.0                   0.204545
# 2    EASTERN EUROPE              38       285.0                   0.133333
# 3   SOUTHERN AFRICA               8        70.0                   0.114286
# 4    WESTERN EUROPE              21       199.0                   0.105528
# 5      WESTERN ASIA              27       299.0                   0.090301
# 6   NORTHERN EUROPE               9       108.0                   0.083333
# 7   NORTHERN AFRICA              16       256.0                   0.062500
# 8      CENTRAL ASIA               5        80.0                   0.062500
# 9   CENTRAL AMERICA              10       182.0                   0.054945
# 10    SOUTH AMERICA              19       426.0                   0.044601
# 11    MIDDLE AFRICA               8       202.0                   0.039604
# 12   SOUTHEAST ASIA              25       682.0                   0.036657
# 13   EASTERN AFRICA              17       483.0                   0.035197
# 14   WESTERN AFRICA              13       442.0                   0.029412
# 15          OCEANIA               1        45.0                   0.022222
# 16       SOUTH ASIA              21      2029.0                   0.010350
# 17        EAST ASIA               3      1648.0                   0.001820
